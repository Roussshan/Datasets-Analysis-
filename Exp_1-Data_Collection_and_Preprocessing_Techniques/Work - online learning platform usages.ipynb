# %% [markdown]
# # Online Learning Platform Usages

# %% [markdown]
# ## Import Required Library

# %%
import pandas as pd
import numpy as np
import os 
for dirname, _, filename in os.walk (r"E:\WORK\Data Sets\online_learning_platform_usage_dataset.csv"):
    for filename in filenames : 
        print (os.path.join (dirname, filename))

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv(r"E:\WORK\Data Sets\online_learning_platform_usage_dataset.csv")

# %% [markdown]
# ### Display First Five Dataset

# %%
df.head()
# Out:
#    user_id age_group                  role primary_platform learning_device  \
# 0        1     35-44  Working Professional              edX          Laptop
# 1        2       45+                 Other              edX          Mobile
# 2        3     25-34            Freelancer       Skillshare         Desktop
# 3        4       45+  Working Professional            Udemy          Mobile
# 4        5       45+  Working Professional     Khan Academy          Mobile
#
#    hours_per_week learning_purpose content_type_preference  \
# 0              10    Career Growth                    Text
# 1              12    Career Growth                    Text
# 2               2         Academic                    Text
# 3               3    Career Growth                   Mixed
# 4              10            Hobby                   Video
#
#    completion_rate_percent  satisfaction_score
# 0                       34                   5
# 1                       17                   3
# ...

# %% [markdown]
# ### Display Number of Rows and Columns

# %%
df.shape
# Out:
# (420, 10)

# %%
df['role'][3]
# Out:
# 'Working Professional'
